# %% [markdown]
# ## NETFLIX DATA ANALYSIS PYTHON PROJECT

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
import seaborn as sns

# %% [markdown]
# ### Import Raw data

# %%
data = pd.read_csv(r"C:\Users\kacha\OneDrive\Desktop\Data Analyst prep\dATA ANALYSIS PROJECT PYTHON\Netfilx Data Analysis python project\Netflix.csv")

# %% [markdown]
# ### Basic information about the dataset

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Task 1: Is there any duplicate Record in the dataset? If yes,then remove all the duplicate records.

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace= True)

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Task 2: Is there any Null value present in any column? Show with the Heat-map.

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### Heat-Map using Seaborn Library

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ###  Q.1. For 'House of Cards' what is the Show Id and Who is the Director of this Show?

# %%
data[data['Title'] == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# #### str.contains()

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ####  loc()

# %%
data.loc[data['Title']  == 'House of Cards', ['Show_Id', 'Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ### Q.2. In which year Highest number of TV Shows and Movies were released? Show with Bar Graph

# %%
# Change the Release_date data type from string to Datetime

data['date_new'] = pd.to_datetime(data['Release_Date'], format='%B %d, %Y', errors='coerce')

# %%
data['date_new'].dt.year.value_counts()  # it counts the occurrence of all individual year in datw column
# Out:
# date_new
# 2019.0    2137
# 2020.0    2009
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# #### Bar Graph

# %%
data['date_new'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='date_new'>

# %% [markdown]
# ### Q.3. How many Movies and Shows are in dataset? show with Bar Graph.

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# countplot()

# %%
sns.countplot(x = 'Category', data = data, palette= 'Set2')
# Out:
# C:\Users\kacha\AppData\Local\Temp\ipykernel_22448\251008174.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Category', data = data, palette= 'Set2')
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Q.4. Show all the Movies that were Release in year 2020

# %%
data[(data['Category'] == 'Movie') & (data['date_new'].dt.year == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ###  Q.5. Show only titles of all TV Shows that realeased in India

# %%
data['Title'][(data['Category']== 'TV Show') & (data['Country']== 'India')]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q.6. Show  top 10  directors who gave the highest number of TV shows and Movies to Netflix

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: count, dtype: int64

# %% [markdown]
# ### Q.7. Show all Records where "Category is Movie" and 'Type is Comedies' or 'Country is United Kingdom'

# %%
data[((data['Category']== 'Movie') & (data['Type']== 'Comedies')) | (data['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ###  Q.8. In How many Movies/ Shows, Tom Cruise was cast?

# %%
data[data['Cast'].str.contains('Tom Cruise',  na = False)]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description   date_new Minutes  \
# 3860  Through chance, human action, past history and... 2020-01-01     189
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01     134
#
#      Unit
# 3860  min
# 5071  min

# %% [markdown]
# ### Q.9. What are the different Ratings defined by Netflix?

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Total number of ratings defined
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# ### Q. 10. How many Movies got 'TV-14' Rating in Canada

# %%
data[(data['Category']== 'Movie') & (data['Rating']== 'TV-14') & (data['Country']== 'Canada')].shape
# Out:
# (11, 14)

# %% [markdown]
# ### Q.11. How Many TV Shows got the 'R' Rating after year 2018?

# %%
data[(data['Category'] == 'TV Show') & (data['Rating']== 'R') & (data['date_new'].dt.year > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description   date_new
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %% [markdown]
# ### Q.12. What is the Maximum Duration of Movie/show on Netflix?

# %%
data[['Minutes', 'Unit']] = data['Duration'].str.split(' ', expand = True)

# %%
data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# ### Q.13. Which Individual Country has the highest No. of TV Shows?

# %%
data_tv_shows = data[data['Category'] == 'TV Show']

# %%
data_tv_shows['Country'].value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ### Q.14. Sort the dataset by Year

# %%
data['Release_year'] = data['date_new'].dt.year
data.sort_values(by ='Release_year', ascending= False)
# Out:
#      Show_Id Category                       Title      Director  \
# 4173   s4174  TV Show                     Monarca           NaN
# 4966   s4966  TV Show         Pretend It’s a City           NaN
# 3472   s3473  TV Show         Kuroko's Basketball           NaN
# 3709   s3710    Movie                London Heist  Mark McQueen
# 1002   s1003    Movie                 Blue Streak  Les Mayfield
# ...      ...      ...                         ...           ...
# 6952   s6951  TV Show                  The Tudors           NaN
# 6998   s6997  TV Show               The West Wing           NaN
# 7448   s7447  TV Show                     Vroomiz           NaN
# 7524   s7523  TV Show  Weird Wonders of the World           NaN
# 7655   s7654  TV Show           Women Behind Bars           NaN
#
#                                                    Cast  \
# 4173  Irene Azuela, Juan Manuel Bernal, Osvaldo Bena...
# 4966                                      Fran Lebowitz
# ...

# %% [markdown]
# ### Q.15. Find all the Instances where:
#
# #### Category is 'Movie'and Type is 'Dramas'
#
# #### OR
#
# #### Category is 'TV Show'and Type is 'Kids TV'

# %%
data[((data['Category'] == 'Movie') & (data['Type'].str.contains('Dramas'))) | ((data['Category'] == 'TV Show') & (data['Type'].str.contains("Kids' TV")))]
# Out:
#      Show_Id Category        Title           Director  \
# 1         s2    Movie        07:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7778   s7777    Movie     Zokkomon   Satyajit Bhatkal
# 7779   s7778  TV Show  Zombie Dumb                NaN
# 7782   s7781    Movie          Zoo       Shlok Sharma
# 7784   s7783    Movie         Zozo        Josef Fares
# 7785   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...
